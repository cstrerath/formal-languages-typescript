// %%
import { display } from "tslab";
import { readFileSync } from "fs";

const css = readFileSync("../style.css", "utf8");
display.html(`<style>${css}</style>`);
// Out:
// <style><link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>
// <link href="http://fonts.googleapis.com/css?family=Sacramento" rel="stylesheet" type="text/css">
//
// <style>
//
// @font-face {
//     font-family: "Computer Modern";
//     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
// }
//
// .container { width: 100% }
//
// /* Formatting for header cells */
// ...

// %%
const { execSync } = await import('child_process');
console.log(execSync('npm install chevrotain@10').toString());
console.log(execSync('npm install readline-sync').toString());
console.log(execSync('npm install @viz-js/viz').toString());
import { createToken, Lexer, CstParser, IToken,} from "chevrotain";
import { instance } from "@viz-js/viz";
// Out:
// up to date, audited 10 packages in 2s
//
// found 0 vulnerabilities
// up to date, audited 10 packages in 2s
//
// found 0 vulnerabilities
// up to date, audited 10 packages in 2s
//
// found 0 vulnerabilities

// %% [markdown]
// # Dealing with Conflicts
//
// This file shows how `Ply` deals with *shift-reduce* and *reduce-reduce* conflicts.
// The following grammar is *ambiguous* because it does not specify the precedence of the arithmetical operators:
// ```
//     expr : expr '+' expr
//          | expr '*' expr
//          | NUMBER
//          ;
// ```

// %% [markdown]
// ## Specification of the Scanner
//
// We implement a minimal scanner for arithmetic expressions.

// %%
// ============================================================================
// Dealing with Conflicts (Chevrotain + Viz.js + tslab display.html)
// Ambiguous grammar (no precedence), LL-safe + tslab visualization
// ============================================================================

import {
  createToken,
  Lexer,
  CstParser,
  type CstNode
} from "chevrotain";

// ----------------------------------------------------------------------------
// 1. Token Specification (Scanner)
// ----------------------------------------------------------------------------

const NumberTok = createToken({ name: "NUMBER", pattern: /0|[1-9][0-9]*/ });
const Plus = createToken({ name: "Plus", pattern: /\+/ });
const Mult = createToken({ name: "Mult", pattern: /\*/ });
const WhiteSpace = createToken({
  name: "WhiteSpace",
  pattern: /[ \t\n\r]+/,
  group: Lexer.SKIPPED,
});

const allTokens = [WhiteSpace, Plus, Mult, NumberTok];
const ArithmeticLexer = new Lexer(allTokens);

// ----------------------------------------------------------------------------
// 2. Parser (right-recursive, no precedence)
// ----------------------------------------------------------------------------
//
//   expr  →  NUMBER rest
//   rest  →  ('+'|'*') expr | ε
//
// Ambiguous like PLY grammar but LL-safe for Chevrotain.

class AmbiguousExprParser extends CstParser {
  constructor() {
    super(allTokens);
    const $: any = this;

    $.RULE("expr", () => {
      $.CONSUME(NumberTok);
      $.OPTION(() => {
        $.SUBRULE($.rest);
      });
    });

    $.RULE("rest", () => {
      $.OR([
        {
          ALT: () => {
            $.OR2([
              { ALT: () => $.CONSUME(Plus) },
              { ALT: () => $.CONSUME(Mult) },
            ]);
            $.SUBRULE($.expr);
          },
        },
      ]);
    });

    this.performSelfAnalysis();
  }
}

const parser = new AmbiguousExprParser();

// ----------------------------------------------------------------------------
// 3. CST → Tuple-like AST
// ----------------------------------------------------------------------------

function cstToTuple(node: CstNode | any): any {
  if (!node || !node.name) return null;

  switch (node.name) {
    case "expr": {
      const num = node.children.NUMBER?.[0]?.image;
      const rest = node.children.rest ? cstToTuple(node.children.rest[0]) : null;
      return rest ? [rest[0], parseInt(num, 10), rest[1]] : parseInt(num, 10);
    }

    case "rest": {
      const op = node.children.Plus ? "+" : node.children.Mult ? "*" : "?";
      const right = cstToTuple(node.children.expr[0]);
      return [op, right];
    }
  }
  return null;
}

// ----------------------------------------------------------------------------
// 4. tuple2dot (Graphviz DOT string generator)
// ----------------------------------------------------------------------------

function tuple2dot(t: any): string {
  let dot = "digraph G {\n  node [shape=circle];\n";
  let counter = 0;

  function walk(node: any, parent?: string): string {
    const id = "n" + counter++;
    const label = Array.isArray(node) ? node[0] : String(node);
    dot += `  ${id} [label="${label}"];\n`;
    if (parent) dot += `  ${parent} -> ${id};\n`;
    if (Array.isArray(node)) {
      for (let i = 1; i < node.length; i++) walk(node[i], id);
    }
    return id;
  }

  walk(t);
  dot += "}";
  return dot;
}

// ----------------------------------------------------------------------------
// 5. parse() and test() (tslab + Viz.js instance())
// ----------------------------------------------------------------------------

function parse(s: string): any {
  const lexResult = ArithmeticLexer.tokenize(s);
  parser.input = lexResult.tokens;

  // ✅ FIX: TypeScript kennt parser.expr() nicht → dynamischer Aufruf
  const cst = (parser as any).expr();

  if (parser.errors.length > 0) {
    console.error("Syntax error:", parser.errors);
    return null;
  }

  const ast = cstToTuple(cst);
  console.log(ast);
  return ast;
}

async function test(s: string) {
  const t = parse(s);
  if (!t) return;
  const dot = tuple2dot(t);

  const viz = await instance();                        // moderne Viz.js API
  const svg = await viz.renderString(dot, { format: "svg" });

  display.html(svg);                                   // ✅ direkt im Notebook anzeigen

  return t;
}

// ----------------------------------------------------------------------------
// Example
// ----------------------------------------------------------------------------

await test("1+2*3")
await test("4*5+6")
// Out:
// [ '+', 1, [ '*', 2, 3 ] ]
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 14.0.1 (20251006.0113)
//  -->
// <!-- Title: G Pages: 1 -->
// <svg width="125pt" height="188pt"
//  viewBox="0.00 0.00 125.00 188.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 184)">
// <title>G</title>
// <polygon fill="white" stroke="none" points="-4,4 -4,-184 121,-184 121,4 -4,4"/>
// <!-- n0 -->
// <g id="node1" class="node">
// <title>n0</title>
// <ellipse fill="none" stroke="black" cx="45" cy="-162" rx="18" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="45" y="-157.8" font-family="Times,serif" font-size="14.00">+</text>
// </g>
// <!-- n1 -->
// <g id="node2" class="node">
// <title>n1</title>
// ...

// %% [markdown]
// ## Specification of the Parser

// %%
class AmbiguousExprParser extends CstParser {
  constructor() {
    super(allTokens);
    const $: any = this;

    $.RULE('expr', () => {
      $.CONSUME(NumberTok);
      $.OPTION(() => {
        $.SUBRULE($.rest);
      });
    });

    $.RULE('rest', () => {
      $.OR([
        {
          ALT: () => {
            $.OR2([{ ALT: () => $.CONSUME(Plus) }, { ALT: () => $.CONSUME(Mult) }]);
            $.SUBRULE($.expr);
          },
        },
      ]);
    });

    this.performSelfAnalysis();
  }
}

const parser = new AmbiguousExprParser();

// %% [markdown]
// The *start variable* of our grammar is `expr`, but we don't have to specify that.  The default
// start variable is the first variable that is defined.

// %% [markdown]
// We can specify multiple expressions in a single rule.  In this case, we have used the `pass`statement
// as we just want to generate the *shift/reduce conflicts* that are associated with this grammar.

// %%
function cstToTuple(node: CstNode | any): any {
  if (!node || !node.name) return null;

  switch (node.name) {
    case 'expr': {
      const num = node.children.NUMBER?.[0]?.image;
      const rest = node.children.rest ? cstToTuple(node.children.rest[0]) : null;
      return rest ? [rest[0], parseInt(num, 10), rest[1]] : parseInt(num, 10);
    }

    case 'rest': {
      const op = node.children.Plus
        ? '+'
        : node.children.Mult
        ? '*'
        : '?';
      const right = cstToTuple(node.children.expr[0]);
      return [op, right];
    }
  }
  return null;
}
// Out:
// 1:27 - Cannot find name 'CstNode'.
// 1:27 - Parameter 'node' of exported function has or is using private name 'CstNode'.

// %% [markdown]
// If we want to generate a parse tree, we have to do more work.

// %%
function tuple2dot(t: any): string {
  let dot = 'digraph G {\n  node [shape=circle];\n';
  let counter = 0;

  function walk(node: any, parent?: string): string {
    const id = 'n' + counter++;
    let label = '';

    if (Array.isArray(node)) {
      label = node[0];
    } else {
      label = String(node);
    }
    dot += `  ${id} [label="${label}"];\n`;

    if (parent) {
      dot += `  ${parent} -> ${id};\n`;
    }

    if (Array.isArray(node) && node.length > 1) {
      for (let i = 1; i < node.length; i++) {
        walk(node[i], id);
      }
    }
    return id;
  }

  walk(t);
  dot += '}';
  return dot;
}

// %% [markdown]
// We define `p_error`in order to prevent a warning.

// %%
def p_error(p):
    print(f'Syntax error.')

// %% [markdown]
// Setting the optional argument `write_tables` to `False` <B style="color:red">is required</B> to prevent an obscure bug where the parser generator tries  to read an empty parse table.

// %%
function parse(s: string): any {
  const lexResult = ArithmeticLexer.tokenize(s);
  parser.input = lexResult.tokens;
  const cst = parser.expr();

  if (parser.errors.length > 0) {
    console.error('Syntax error:', parser.errors);
    return null;
  }

  const ast = cstToTuple(cst);
  console.log(ast);
  return ast;
}

// %% [markdown]
// Let's look at the action table that is generated.  Note that all *conflicts are resolved in favour of shifting*.

// %%
!cat parser.out

// %% [markdown]
// The function `test(s)` takes a string `s` as its argument an tries to parse this string.  If all goes well, an abstract syntax tree is returned.
// If the string can't be parsed,  an error message is printed by the parser.

// %%
async function test(s: string) {
  const t = parse(s);
  if (!t) return;
  const d = tuple2dot(t);

  const viz = new Viz({ Module, render });
  const svg = await viz.renderString(d);
  const div = document.createElement('div');
  div.innerHTML = svg;
  document.body.appendChild(div);

  return t;
}

// %% [markdown]
// The next example shows that this parser does not produce the abstract syntax that reflects the precedences of the arithmetical operators.

// %%
await test('1*2+3')

// %% [markdown]
// Due to the fact that all shift-reduce conflicts are resolved in favor of shift, all operators have the same precedence and effectively associate to the right.

// %%
await test('2+3+4')
