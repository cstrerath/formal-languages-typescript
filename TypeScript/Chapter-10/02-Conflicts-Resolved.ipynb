// %%
import { display } from "tslab";
import { readFileSync } from "fs";

const css = readFileSync("../style.css", "utf8");
display.html(`<style>${css}</style>`);
// Out:
// <style><link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
// <link href='http://fonts.googleapis.com/css?family=Philosopher:400,700,400italic,700italic' rel='stylesheet' type='text/css'>
// <link href="http://fonts.googleapis.com/css?family=Sacramento" rel="stylesheet" type="text/css">
//
// <style>
//
// @font-face {
//     font-family: "Computer Modern";
//     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
// }
//
// .container { width: 100% }
//
// /* Formatting for header cells */
// ...

// %%
const { execSync } = await import('child_process');
console.log(execSync('npm install chevrotain@10').toString());
console.log(execSync('npm install @viz-js/viz').toString());
import { createToken, Lexer, CstParser, IToken, type CstNode} from "chevrotain";
import { instance } from "@viz-js/viz";
// Out:
// up to date, audited 10 packages in 844ms
//
// found 0 vulnerabilities
// up to date, audited 10 packages in 837ms
//
// found 0 vulnerabilities

// %% [markdown]
// # Resolving Conflicts Using *Precedence Declarations*
//
// This file shows how *shift/reduce* and *reduce/reduce* conflicts can be resolved using *operator precedence declarations*.
// The following grammar is *ambiguous* because it does not specify the precedence of the arithmetical operators:
// ```
//     expr : expr '+' expr
//          | expr '-' expr
//          | expr '*' expr
//          | expr '/' expr
//          | expr '^' expr
//          | '(' expr ')'
//          | NUMBER
//          ;
// ```
// We will see how the use of precedence declarations can be used to resolve *shift/reduce-conflicts*.

// %% [markdown]
// ## Specification of the Scanner
//
// We implement a minimal scanner for arithmetic expressions.

// %%
// ---------------------------------------------------------------------------
// 1. Tokens / Scanner
// ---------------------------------------------------------------------------

const WhiteSpace = createToken({
  name: "WhiteSpace",
  pattern: /[ \t\n\r]+/,
  group: Lexer.SKIPPED,
});

const NumberTok = createToken({ name: "NUMBER", pattern: /0|[1-9][0-9]*/ });
const Plus = createToken({ name: "Plus", pattern: /\+/ });
const Minus = createToken({ name: "Minus", pattern: /-/ });
const Mult = createToken({ name: "Mult", pattern: /\*/ });
const Div = createToken({ name: "Div", pattern: /\// });
const Pow = createToken({ name: "Pow", pattern: /\^/ });
const LParen = createToken({ name: "LParen", pattern: /\(/ });
const RParen = createToken({ name: "RParen", pattern: /\)/ });

const allTokens = [
  WhiteSpace,
  NumberTok,
  Plus,
  Minus,
  Mult,
  Div,
  Pow,
  LParen,
  RParen,
];

const ArithmeticLexer = new Lexer(allTokens);

// %% [markdown]
// ## Specification of the Parser

// %%
// ---------------------------------------------------------------------------
// 2. Parser mit Präzedenz / Assoziativität
// ---------------------------------------------------------------------------

class ArithmeticParser extends CstParser {
  // Typ-Deklarationen (damit TS die Methoden kennt)
  public expression!: (idxInRule?: number) => CstNode;
  public additionExpression!: (idxInRule?: number) => CstNode;
  public multiplicationExpression!: (idxInRule?: number) => CstNode;
  public powerExpression!: (idxInRule?: number) => CstNode;
  public primary!: (idxInRule?: number) => CstNode;
  public addOp!: (idxInRule?: number) => CstNode;
  public mulOp!: (idxInRule?: number) => CstNode;

  constructor() {
    super(allTokens);
    const $: any = this;

    $.RULE("expression", () => {
      $.SUBRULE($.additionExpression);
    });

    // +, -  (links assoziativ)
    $.RULE("additionExpression", () => {
      $.SUBRULE($.multiplicationExpression);
      $.MANY(() => {
        $.SUBRULE($.addOp);
        $.SUBRULE2($.multiplicationExpression);
      });
    });

    // *, /  (links assoziativ)
    $.RULE("multiplicationExpression", () => {
      $.SUBRULE($.powerExpression);
      $.MANY(() => {
        $.SUBRULE($.mulOp);
        $.SUBRULE2($.powerExpression);
      });
    });

    // ^  (rechts assoziativ)
    $.RULE("powerExpression", () => {
      $.SUBRULE($.primary);
      $.OPTION(() => {
        $.CONSUME(Pow);
        $.SUBRULE2($.powerExpression);
      });
    });

    $.RULE("primary", () => {
      $.OR([
        { ALT: () => $.CONSUME(NumberTok) },
        {
          ALT: () => {
            $.CONSUME(LParen);
            $.SUBRULE($.expression);
            $.CONSUME(RParen);
          },
        },
      ]);
    });

    // Operator-Regeln
    $.RULE("addOp", () => {
      $.OR([{ ALT: () => $.CONSUME(Plus) }, { ALT: () => $.CONSUME(Minus) }]);
    });

    $.RULE("mulOp", () => {
      $.OR([{ ALT: () => $.CONSUME(Mult) }, { ALT: () => $.CONSUME(Div) }]);
    });

    this.performSelfAnalysis();
  }
}

const parser = new ArithmeticParser();

// ---------------------------------------------------------------------------
// 3. CST → AST (PLY-Stil: ('+', left, right), …)
// ---------------------------------------------------------------------------
type AST = number | [string, AST, AST];

// wichtig: "WithDefaults" verwenden, sonst fehlt visit()
const BaseVisitor = parser.getBaseCstVisitorConstructorWithDefaults();

class ToAstVisitor extends BaseVisitor {
  constructor() {
    super();
    // In v10 NICHT mehr validateVisitor() aufrufen!
  }

  expression(ctx: any): AST {
    return this.visit(ctx.additionExpression);
  }

  additionExpression(ctx: any): AST {
    const parts = ctx.multiplicationExpression as CstNode[];
    let left = this.visit(parts[0]);
    const ops = (ctx.addOp ?? []) as CstNode[];
    for (let i = 1; i < parts.length; i++) {
      const opSym = this.visit(ops[i - 1]);
      const right = this.visit(parts[i]);
      left = [opSym, left, right];
    }
    return left;
  }

  multiplicationExpression(ctx: any): AST {
    const parts = ctx.powerExpression as CstNode[];
    let left = this.visit(parts[0]);
    const ops = (ctx.mulOp ?? []) as CstNode[];
    for (let i = 1; i < parts.length; i++) {
      const opSym = this.visit(ops[i - 1]);
      const right = this.visit(parts[i]);
      left = [opSym, left, right];
    }
    return left;
  }

  powerExpression(ctx: any): AST {
    const base = this.visit(ctx.primary[0]);
    if (ctx.Pow) {
      const right = this.visit(ctx.powerExpression[0]);
      return ["^", base, right];
    }
    return base;
  }

  primary(ctx: any): AST {
    if (ctx.NUMBER) return Number(ctx.NUMBER[0].image);
    return this.visit(ctx.expression[0]);
  }

  addOp(ctx: any): string {
    if (ctx.Plus) return "+";
    if (ctx.Minus) return "-";
    throw new Error("unexpected addOp");
  }

  mulOp(ctx: any): string {
    if (ctx.Mult) return "*";
    if (ctx.Div) return "/";
    throw new Error("unexpected mulOp");
  }
}

const toAst = new ToAstVisitor();

// %% [markdown]
// The *start variable* of our grammar is `expr`, but we don't have to specify that.  The default
// start variable is the first variable that is defined.

// %% [markdown]
// The following *operator precedence declarations* declare that the operators `'+'`and `'-'` have a lower precedence than the operators `'*'`and `'/'`.  The operator `'^'` has the highest precedence.  Furthermore, the declarations specify that the operators  `'+'`, `'-'`, `'*'`, and `'/'` are *left associative*, while the operator `'^'` is declared as *right associative* using the keyword `right`.
// Operators can also be defined as being *non-associative* using the keyword `nonassoc`.

// %%
// ---------------------------------------------------------------------------
// 4. Parser Wrapper
// ---------------------------------------------------------------------------

function parse(input: string): AST {
  const lex = ArithmeticLexer.tokenize(input);
  parser.input = lex.tokens;
  const cst = parser.expression();
  if (parser.errors.length) throw new Error(parser.errors[0].message);
  return toAst.visit(cst);
}

// %%
// ---------------------------------------------------------------------------
// 5. tuple2dot (AST → Graphviz)
// ---------------------------------------------------------------------------

function tuple2dot(t: any): string {
  let dot = "digraph G {\n  node [shape=circle];\n";
  let counter = 0;

  function walk(node: any, parent?: string): string {
    const id = "n" + counter++;
    const label = Array.isArray(node) ? node[0] : String(node);
    dot += `  ${id} [label="${label}"];\n`;
    if (parent) dot += `  ${parent} -> ${id};\n`;
    if (Array.isArray(node)) {
      for (let i = 1; i < node.length; i++) walk(node[i], id);
    }
    return id;
  }

  walk(t);
  dot += "}";
  return dot;
}

// %% [markdown]
// As there are no warnings all conflicts have been resolved using the precedence declarations.
// Let's look at the action table that is generated.

// %%
function dumpChevrotainGrammar(p: CstParser) {
    const chevrotainVersion = (Lexer as any).VERSION ?? "10.x";
    console.log(`Created by Chevrotain v${chevrotainVersion} (https://chevrotain.io)`);
  console.log("\nGrammar\n");

  // getGAstProductions() liefert interne Strukturen, hier casten wir explizit
  const productions = (p as any).getGAstProductions() as Record<
    string,
    { definition: any[] }
  >;

  let ruleId = 0;
  for (const [name, prod] of Object.entries(productions)) {
    // jedes production.definition-Element kann ein Terminal oder Nonterminal sein
    const rhs = (prod.definition || [])
      .map((d: any) => d.terminalName || d.nonTerminalName || "")
      .filter(Boolean)
      .join(" ");
    console.log(`Rule ${ruleId++}     ${name} -> ${rhs}`);
  }

  console.log("\nParsing method: LL(k)\n");
}

dumpChevrotainGrammar(parser);
// Out:
// Created by Chevrotain v10.x (https://chevrotain.io)
//
// Grammar
//
// Rule 0     expression -> additionExpression
// Rule 1     additionExpression -> multiplicationExpression
// Rule 2     multiplicationExpression -> powerExpression
// Rule 3     powerExpression -> primary
// Rule 4     primary ->
// Rule 5     addOp ->
// Rule 6     mulOp ->
//
// Parsing method: LL(k)

// %% [markdown]
// The function `test(s)` takes a string `s` as its argument an tries to parse this string.  If all goes well, an abstract syntax tree is returned.
// If the string can't be parsed,  an error message is printed by the parser.

// %%
// ---------------------------------------------------------------------------
// 7. Testfunktion (Notebook-Style, zeigt SVG im Notebook)
// ---------------------------------------------------------------------------

async function test(s: string) {
  const t = parse(s);
  const dot = tuple2dot(t);

  const viz = await instance();
  const svg = await viz.renderString(dot, { format: "svg" });

  // Im VS Code / Jupyter Notebook:
  // @ts-ignore
  display.html(svg);

  return t;
}

// %%
await test('2^3^4*5+6-7/8^9')
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 14.0.1 (20251006.0113)
//  -->
// <!-- Title: G Pages: 1 -->
// <svg width="260pt" height="404pt"
//  viewBox="0.00 0.00 260.00 404.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 400)">
// <title>G</title>
// <polygon fill="white" stroke="none" points="-4,4 -4,-400 256,-400 256,4 -4,4"/>
// <!-- n0 -->
// <g id="node1" class="node">
// <title>n0</title>
// <ellipse fill="none" stroke="black" cx="126" cy="-378" rx="18" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="126" y="-373.8" font-family="Times,serif" font-size="14.00">&#45;</text>
// </g>
// <!-- n1 -->
// <g id="node2" class="node">
// <title>n1</title>
// ...

// %%
await test('1+2*3^4')
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 14.0.1 (20251006.0113)
//  -->
// <!-- Title: G Pages: 1 -->
// <svg width="152pt" height="260pt"
//  viewBox="0.00 0.00 152.00 260.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 256)">
// <title>G</title>
// <polygon fill="white" stroke="none" points="-4,4 -4,-256 148,-256 148,4 -4,4"/>
// <!-- n0 -->
// <g id="node1" class="node">
// <title>n0</title>
// <ellipse fill="none" stroke="black" cx="45" cy="-234" rx="18" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="45" y="-229.8" font-family="Times,serif" font-size="14.00">+</text>
// </g>
// <!-- n1 -->
// <g id="node2" class="node">
// <title>n1</title>
// ...

// %%
await test('1 * 2 + 3^4^5')
// Out:
// <?xml version="1.0" encoding="UTF-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Generated by graphviz version 14.0.1 (20251006.0113)
//  -->
// <!-- Title: G Pages: 1 -->
// <svg width="233pt" height="260pt"
//  viewBox="0.00 0.00 233.00 260.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
// <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 256)">
// <title>G</title>
// <polygon fill="white" stroke="none" points="-4,4 -4,-256 229,-256 229,4 -4,4"/>
// <!-- n0 -->
// <g id="node1" class="node">
// <title>n0</title>
// <ellipse fill="none" stroke="black" cx="99" cy="-234" rx="18" ry="18"/>
// <text xml:space="preserve" text-anchor="middle" x="99" y="-229.8" font-family="Times,serif" font-size="14.00">+</text>
// </g>
// <!-- n1 -->
// <g id="node2" class="node">
// <title>n1</title>
// ...
